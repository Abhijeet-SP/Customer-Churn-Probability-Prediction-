# %% [markdown]
# # Data Cleanup

# %%
import numpy as np
import pandas as pd

# %%
import warnings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/kaggle/input/datasets/abhijeetsp015/ml-project-data/raw_dirty_data_saas.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117374 entries, 0 to 117373
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   customer_id                  117374 non-null  object
#  1   company_size                 117374 non-null  object
#  2   industry                     117374 non-null  object
#  3   region                       117374 non-null  object
#  4   subscription_plan            117374 non-null  object
#  5   contract_type                117374 non-null  object
#  6   tenure_months                117374 non-null  object
#  7   monthly_revenue              112623 non-null  object
#  8   seats_licensed               112663 non-null  float64
#  9   login_frequency              117374 non-null  float64
#  10  feature_usage_score          111542 non-null  object
#  11  avg_session_duration_mins    117374 non-null  float64
# ...

# %%
data.head(10)
# Out:
#     customer_id company_size       industry         region subscription_plan  \
# 0  CUST-0028736   Mid-Market  Manufacturing         Europe             Basic
# 1  CUST-0104506          SMB     Technology         Europe             Basic
# 2  CUST-0003425      Startup      Education         Europe             Basic
# 3  CUST-0025254      Startup      Education  North America        Enterprise
# 4  CUST-0011252   Mid-Market      Education           APAC               Pro
# 5  CUST-0064132          SMB      Logistics  North America             Basic
# 6  CUST-0028883          SMB      Education  North America        Enterprise
# 7  CUST-0089526          SMB     Technology           APAC             Basic
# 8  CUST-0049809          SMB  Manufacturing  North America             Basic
# 9  CUST-0040975          SMB     Healthcare  Latin America        Enterprise
#
#   contract_type tenure_months monthly_revenue  seats_licensed  \
# ...

# %% [markdown]
# ### removing uncessary columns
#
# * random_id_hash — random hash, no ML value
# * account_color — UI preference, not churn signal
# * theme_preference — UI preference, not churn signal
# * dummy_score — literally named dummy, 9,468 nulls

# %%
cols_to_drop = [
    'random_id_hash',
    'account_color',
    'theme_preference',
    'dummy_score',
    'referral_code'
]

data = data.drop(columns=cols_to_drop)
print("Remaining columns:", data.shape[1])
# Out:
# Remaining columns: 27

# %% [markdown]
# ### Datatype change and handiling nulls in particular columns.
# 1. Tenure months to float
# 2. Monthly revenue to float
# 3. feature_usage_score to float
# 4. signup_date to date format mixed
#
# data2['column_name'] = pd.to_numeric(data2['column_name'], errors='coerce') -- little unwanted values get formated to null using errors='coerce'.
# Lets clean them first.

# %%
print('Null values before changing datatype')
print(data.isnull().sum()[['tenure_months','monthly_revenue','feature_usage_score','signup_date']])
# Out:
# Null values before changing datatype
# tenure_months             0
# monthly_revenue        4751
# feature_usage_score    5832
# signup_date            3521
# dtype: int64

# %%
# Data Cleaning operations 
data['tenure_months'] = data['tenure_months'].str.strip().str.lower().str.replace("'", '')
data['monthly_revenue'] = data['monthly_revenue'].str.strip().str.lower().str.replace("'", '')
data['feature_usage_score'] = data['feature_usage_score'].str.strip().str.lower().str.replace("'", '')

# %%
# Changing Datatype 
data['tenure_months'] = pd.to_numeric(data['tenure_months'])
data['monthly_revenue'] = pd.to_numeric(data['monthly_revenue'])
data['feature_usage_score'] = pd.to_numeric(data['feature_usage_score'])
data['signup_date'] = pd.to_datetime(data['signup_date'], format="mixed")

# %%
print('Null values after changing datatype')
print(data.isnull().sum()[['tenure_months','monthly_revenue','feature_usage_score','signup_date']])
# Out:
# Null values after changing datatype
# tenure_months             0
# monthly_revenue        4751
# feature_usage_score    5832
# signup_date            3521
# dtype: int64

# %%
print(data[['tenure_months','monthly_revenue','feature_usage_score','signup_date']].dtypes)
# Out:
# tenure_months                   int64
# monthly_revenue               float64
# feature_usage_score           float64
# signup_date            datetime64[ns]
# dtype: object

# %% [markdown]
# ### Handling the duplicates
# 1. Initally from the main column - customer_id. Drop any duplicate customer to over train our model.

# %%
print("Duplicates before:", data.duplicated().sum())

data = data.drop_duplicates(subset='customer_id', keep='first') # removing on the basis of customer_id
data = data.reset_index(drop=True) # resetting the index
# Out:
# Duplicates before: 1734

# %%
print("Duplicates after:", data.duplicated().sum())
print("New shape:", data.shape)
# Out:
# Duplicates after: 0
# New shape: (115640, 27)

# %% [markdown]
# ### Data Inconsistency

# %%
non_numeric_cols = data.select_dtypes(exclude='number').columns

for col in non_numeric_cols:
    print(f"Column: {col}")
    print("Unique Values:", data[col].nunique())
    print(data[col].dropna().unique()[:20])
    print("-" * 50)
# Out:
# Column: customer_id
# Unique Values: 115640
# ['CUST-0028736' 'CUST-0104506' 'CUST-0003425' 'CUST-0025254'
#  'CUST-0011252' 'CUST-0064132' 'CUST-0028883' 'CUST-0089526'
#  'CUST-0049809' 'CUST-0040975' 'CUST-0025021' 'CUST-0089485'
#  'CUST-0039694' 'CUST-0060873' 'CUST-0005671' 'CUST-0082085'
#  'CUST-0046298' 'CUST-0024590' 'CUST-0012553' 'CUST-0088411']
# --------------------------------------------------
# Column: company_size
# Unique Values: 4
# ['Mid-Market' 'SMB' 'Startup' 'Enterprise']
# --------------------------------------------------
# Column: industry
# Unique Values: 10
# ['Manufacturing' 'Technology' 'Education' 'Logistics' 'Healthcare'
#  'Marketing' 'Retail' 'Legal' 'Real Estate' 'Finance']
# --------------------------------------------------
# Column: region
# Unique Values: 5
# ['Europe' 'North America' 'APAC' 'Latin America' 'Middle East & Africa']
# --------------------------------------------------
# Column: subscription_plan
# Unique Values: 19
# ...

# %%
print(data['subscription_plan'].unique())
print(data['contract_type'].unique())
print(data['onboarding_completed'].unique())
# Out:
# ['Basic' 'Enterprise' 'Pro' 'Free' 'enterprise' 'PRO' 'Pro ' 'Free '
#  'BASIC' 'ENTERPRISE' 'free' 'pro ' 'BASIC ' 'Basic ' 'pro' 'FREE' 'basic'
#  'Enterprise ' 'Ent']
# ['Monthly' 'Yearly' 'month' 'annual' 'MONTHLY' 'YEARLY' 'yearly' 'monthly'
#  'Annual']
# ['No' 'Yes' 'no' 'yes' '0' 'Y' 'YES' 'NO' 'n' '1' 'y' 'N']

# %%
data['subscription_plan'] = data['subscription_plan'].str.replace('Ent', 'Enterprise').str.strip().str.lower()
data['contract_type'] = data['contract_type'].replace({
                                                        'month': 'Monthly',
                                                        'annual': 'Annual'}).str.strip().str.lower()
data['onboarding_completed'] = data['onboarding_completed'].replace({
                                                                        '0': 'no',
                                                                        'Y': 'yes',
                                                                        'n': 'no',
                                                                        '1': 'yes',
                                                                        'y': 'yes',
                                                                        'N': 'no'}).str.strip().str.lower()

# %%
print(data['subscription_plan'].unique())
print(data['contract_type'].unique())
print(data['onboarding_completed'].unique())
# Out:
# ['basic' 'enterpriseerprise' 'pro' 'free' 'enterprise']
# ['monthly' 'yearly' 'annual']
# ['no' 'yes']

# %% [markdown]
# ### Handling remanining Nulls.
#
# Numeric columns: fill nulls with median (robust to outliers)
# customer_satisfaction_score: 9,385 nulls → fill with median
# email_open_rate: 11,710 nulls → fill with median
# training_sessions_attended: 10,507 nulls → fill with median
# signup_date: 3,521 nulls → drop rows (date is needed for feature engineering)

# %%
data.isnull().sum()[data.isnull().sum() > 0]
# Out:
# monthly_revenue                 4692
# seats_licensed                  4628
# feature_usage_score             5740
# last_login_days_ago             6990
# integration_count               6964
# avg_response_time               8036
# customer_satisfaction_score     9238
# discount_applied                5770
# email_open_rate                11536
# training_sessions_attended     10360
# signup_date                     3461
# dtype: int64

# %%
numeric_cols_with_nulls = [
    'monthly_revenue', 'seats_licensed', 'feature_usage_score',
    'last_login_days_ago', 'integration_count', 'avg_response_time',
    'customer_satisfaction_score', 'email_open_rate',
    'training_sessions_attended', 'discount_applied'
]

for col in numeric_cols_with_nulls:
    median_val = data[col].median()
    data[col] = data[col].fillna(median_val)

data = data.dropna(subset=['signup_date'])

print(f"The number of columns with nulls are:- \n{data.isnull().sum()[data.isnull().sum() > 0]}")
print("\nFinal shape:", data.shape)
# Out:
# The number of columns with nulls are:-
# Series([], dtype: int64)
#
# Final shape: (112179, 27)

# %%
data.to_parquet('/kaggle/working/cleaned_data.parquet')
